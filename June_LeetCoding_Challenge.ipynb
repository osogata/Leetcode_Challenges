# %% [markdown]
# # June LeetCoding Challenge

# %% [markdown]
# This notebook records my practices for the May LeetCoding Challenge for the month of June, 2020.
#
# https://leetcode.com/explore/featured/card/june-leetcoding-challenge/

# %% [markdown]
# # 6/1/2020 Invert Binary Tree

# %% [markdown]
# Invert a binary tree.
#
# Example:
#
# ![Capture.JPG](attachment:Capture.JPG)

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None

class Solution:
    def invertTree(root):
        
        if not root:
            return None
        
        # use recursive approach
        right = self.invertTree(root.right)
        left = self.invertTree(root.left)
        
        # do the actual invert
        root.left = right
        root.right = left
        
        return root

# %% [markdown]
# # 6/2/2020 Delete Node in a Linked List

# %% [markdown]
# Write a function to delete a node (except the tail) in a singly linked list, given only access to that node.
#
#
# Example 1:
#
# Input: head = [4,5,1,9], node = 5
# Output: [4,1,9]
# Explanation: You are given the second node with value 5, the linked list should become 4 -> 1 -> 9 after calling your function.
#
# Example 2:
#
# Input: head = [4,5,1,9], node = 1
# Output: [4,5,9]
# Explanation: You are given the third node with value 1, the linked list should become 4 -> 5 -> 9 after calling your function.
#
#
# Note:
#
#     The linked list will have at least two elements.
#     All of the nodes' values will be unique.
#     The given node will not be the tail and it will always be a valid node of the linked list.
#     Do not return anything from your function.

# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution:
    def deleteNode(self, node):
        """
        :type node: ListNode
        :rtype: void Do not return anything, modify node in-place instead.
        """
       
        node.val = node.next.val
        node.next = node.next.next

# %% [markdown]
# # 6/3/2020 Two City Scheduling

# %% [markdown]
# There are 2N people a company is planning to interview. The cost of flying the i-th person to city A is costs[i][0], and the cost of flying the i-th person to city B is costs[i][1].
#
# Return the minimum cost to fly every person to a city such that exactly N people arrive in each city.
#
#
#
# Example 1:
#
# Input: [[10,20],[30,200],[400,50],[30,20]]
# Output: 110
# Explanation:
# The first person goes to city A for a cost of 10.
# The second person goes to city A for a cost of 30.
# The third person goes to city B for a cost of 50.
# The fourth person goes to city B for a cost of 20.
#
# The total minimum cost is 10 + 30 + 50 + 20 = 110 to have half the people interviewing in each city.
#
#
# Note:
#
#     1 <= costs.length <= 100
#     It is guaranteed that costs.length is even.
#     1 <= costs[i][0], costs[i][1] <= 1000

# %%
def twoCitySchedCost(costs):


    # first sort the difference between A and B for each person from largest to smallest
    costs.sort(key = lambda x: abs(x[0] - x[1]), reverse = True)
    print(costs)

    N = len(costs) // 2
    A = 0
    B = 0
    mincost = 0

    for cost in costs:

        if A == N: # if the number of persons going to city A already reaches N (half of the total size)
            mincost += cost[1]
        elif B == N:
            mincost += cost[0]
        elif cost[0] <= cost[1]: # choosing the city with smaller cost 
            A += 1
            mincost += cost[0]
        elif cost[0] > cost[1]:
            B += 1
            mincost += cost[1]

    return mincost

# %%
twoCitySchedCost( [[10,20],[30,200],[400,50],[30,20]])
# Out:
# [[400, 50], [30, 200], [10, 20], [30, 20]]
# 110
